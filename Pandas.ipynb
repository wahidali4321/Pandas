# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## check the pandas library

# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
mydataset = {
    'car' : ["BMW" , 'Volvo' , 'Mercedes'],
    'passings' : [4,5,6]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#         car  passings
# 0       BMW         4
# 1     Volvo         5
# 2  Mercedes         6

# %% [markdown]
# ## Assignment 1 — Create a Student DataFram

# %%
student = {
    'name ' : ["wahid " , "ali" , "Khan" , "akhtar" , "ali"],
    'age ' : [11,22,23,24,25],
    'marks ' : [87 , 89 , 98 , 100 , 99]
}
prin = pd.DataFrame(student)
print(prin)
# Out:
#     name   age   marks
# 0  wahid     11      87
# 1     ali    22      89
# 2    Khan    23      98
# 3  akhtar    24     100
# 4     ali    25      99

# %% [markdown]
# ## Assignment 2 — Access Columns

# %%
student = {
    'name ' : ["wahid " , "ali" , "Khan" , "akhtar" , "ali"],
    'age ' : [11,22,23,24,25],
    'marks ' : [87 , 89 , 98 , 100 , 99]
}
df = pd.DataFrame(student)
print(df.columns)
# Out:
# Index(['name ', 'age ', 'marks '], dtype='object')

# %% [markdown]
# ## Assignment 3 — Filter Students

# %%
data = {
    'name ' : ["ali" , "ahmed" , "usman" , "wahid" , "hamza" , "usman"],
    'age ' : [20,21,22,20,23 , 30],
    'marks ': [75,88,95,65,82 , 11]
}
df = pd.DataFrame(data)
for x in df:
    if x > 80:
        print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       6 df = pd.DataFrame(data)
#       7 for x in df:
# ----> 8     if x > 80:
#       9         print(df.columns)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
import pandas as pd

data = {
    "name": ["ali", "ahmed", "usman", "wahid", "hamza"],
    "age": [20, 21, 22, 20, 23],
    "marks": [75, 88, 95, 65, 82]
}

df = pd.DataFrame(data)

print(df[df["marks"] > 80])
# Out:
#     name  age  marks
# 1  ahmed   21     88
# 2  usman   22     95
# 4  hamza   23     82

# %% [markdown]
# ## add new column

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Ahmed", "Usman", "Wahid", "Hamza"],
    "Age": [20, 21, 22, 20, 23],
    "Marks": [75, 88, 95, 65, 82]
}

df = pd.DataFrame(data)

df["Grade"] = ["B", "A", "A", "C", "A"]

print(df)
# Out:
#     Name  Age  Marks Grade
# 0    Ali   20     75     B
# 1  Ahmed   21     88     A
# 2  Usman   22     95     A
# 3  Wahid   20     65     C
# 4  Hamza   23     82     A

# %% [markdown]
# ## pandas series

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
a  = [1,2,3,4]
df = pd.Series(a)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
y = [11,22,33,44]

df = pd.Series(y)
print(df)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
y = [11,22,33,44]

df = pd.Series(y)
print(df[1])
# Out:
# 22

# %%
names = ["wahid ali" , "akhtar ali" , "shahid" , "naqib"]
df = pd.Series(names , index = ["first" , "last" , "mid" , "last second"])
print(df)
# Out:
# first           wahid ali
# last           akhtar ali
# mid                shahid
# last second         naqib
# dtype: object

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ## Assignment 1 — Create a Series

# %%
x = [10, 20, 30, 40, 50]
df = pd.Series(x)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ## Create a Series with Custom Index

# %%
marks = [75,88,92,65]
df = pd.Series(marks , index = ["Ali" , "Ahmed" , "wahid" , "Usman"])
print(df)
# Out:
# Ali      75
# Ahmed    88
# wahid    92
# Usman    65
# dtype: int64

# %% [markdown]
# ## Assignment 3 — Access Series Element

# %%
num = [10, 20, 30, 40, 50]
df = pd.Series(num)
print(df[0])
print(df[2])
print(df[4])
# Out:
# 10
# 30
# 50

# %% [markdown]
# ## Assignment 4 — Series Operations

# %%
nume = [10, 20, 30, 40, 50]
df = pd.Series(nume)
sum = df + 2
mul = df * 5
print(sum)
print(mul)
# Out:
# 0    12
# 1    22
# 2    32
# 3    42
# 4    52
# dtype: int64
# 0     50
# 1    100
# 2    150
# 3    200
# 4    250
# dtype: int64

# %% [markdown]
# ## Assignment 5 — Find Maximum and Minimum

# %%
import pandas as pd

numbers = [45, 78, 23, 90, 56, 88, 34]

df = pd.Series(numbers)

ma = df.max()
mi = df.min()
su = df.sum()
av = df.mean()

print("Maximum:", ma)
print("Minimum:", mi)
print("Sum:", su)
print("Average:", av)
# Out:
# Maximum: 90
# Minimum: 23
# Sum: 414
# Average: 59.142857142857146

# %% [markdown]
# ## Assignment 1 — Custom Labels

# %%
numbers = [80, 75, 90, 65]
labels = pd.Series(numbers , index = ["Ali" , "Ahmed" , "Wahid" , "Usman"])
print(labels)
# Out:
# Ali      80
# Ahmed    75
# Wahid    90
# Usman    65
# dtype: int64

# %% [markdown]
# ## Assignment 2 — Access Using Labels

# %%
numbers = [50, 60, 70, 80, 90]
df = pd.Series(numbers , index = ['A' , 'B' , 'C' , 'D' , 'D'])
print(df['B'])
print(df['D'])
# Out:
# 60
# D    80
# D    90
# dtype: int64

# %% [markdown]
# ## Assignment 3 — Student Marks

# %%
import pandas as pd

marks = [85, 78, 92, 69, 88]

students = ["Ali", "Ahmed", "Wahid", "Usman", "Hamza"]

df = pd.Series(marks, index=students)

print(df)

print("Wahid's marks:", df["Wahid"])
print("Hamza's marks:", df["Hamza"])
# Out:
# Ali      85
# Ahmed    78
# Wahid    92
# Usman    69
# Hamza    88
# dtype: int64
# Wahid's marks: 92
# Hamza's marks: 88

# %% [markdown]
# ## pandas dataframes

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## Locate Row

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df.loc[[0 , 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# ## install plotty libibray

# %%
# !pip install plotty
# Out:
# ...
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## loading the csv file

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df = pd.read_csv('data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_csv('data.csv')
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# ## using head() option

# %%
df = pd.read_csv("data.csv")
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df = pd.read_csv("data.csv")
print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df = pd.read_csv("data.csv")
print(df.columns)
print(df.to_string())
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# ...

# %%
df = pd.read_csv("data.csv")
print(df['Pulse'])
# Out:
# 0      110
# 1      117
# 2      103
# 3      109
# 4      117
#       ...
# 164    105
# 165    110
# 166    115
# 167    120
# 168    125
# Name: Pulse, Length: 169, dtype: int64

# %% [markdown]
# ## using the tail()

# %%
df = pd.read_csv("data.csv")
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
